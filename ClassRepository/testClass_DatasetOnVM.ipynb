# %%
#!ipcluster start -n 4 --engines=MPI --profile='mpi' # for parallel run: start the engines using terminal

# %%
from ipyparallel import Client
rc=Client(profile='mpi')
view=rc[:]
view.block=True

# %%
sync=view.run('test4Class_DatasetOnVM.py')
sync.display_outputs()
# Out:
# [stdout:0] MPI id=   3 nx=  1024 ny=  1024 nz=  1024
# [stdout:1] MPI id=   2 nx=  1024 ny=  1024 nz=  1024
# [stdout:2]
# MPI id=   0 nx=  1024 ny=  1024 nz=  1024
# Load velocity field cost: 17.82 seconds
# Wavenumber calculation cost: 12.22 seconds
# 3 R-C FFTs cost: 73.55 seconds
# Energy spec calculation cost: 24.38 seconds
# Gaussian filtering calculation cost: 18.81 seconds
# Sharp filtering calculation cost: 11.05 seconds
# Box filtering calculation cost: -22.29 seconds
# [stdout:3] MPI id=   1 nx=  1024 ny=  1024 nz=  1024
# [stdout:4] MPI id=   4 nx=  1024 ny=  1024 nz=  1024
# [stdout:5] MPI id=   5 nx=  1024 ny=  1024 nz=  1024
# [stdout:6] MPI id=   7 nx=  1024 ny=  1024 nz=  1024
# [stdout:7] MPI id=   6 nx=  1024 ny=  1024 nz=  1024

# %%
nproc=rc[0].get('nproc')
for i in range(nproc):
    if(rc[i].get('my_id')==0):
        e0=rc[i]
        id_e0=i
        break

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

#matplotlib.rcParams.update({'font.size': 18})
#matplotlib.rc('xtick', labelsize=20) 
#matplotlib.rc('ytick', labelsize=20)
#matplotlib.rc('xlabel', labelsize=20) 
#matplotlib.rc('ylabel', labelsize=20)
#axis_font = {'size':'14'} #{'fontname':'Arial', 'size':'14'}

SIZE = 12
plt.rc('font', size=SIZE)  # controls default text sizes
plt.rc('axes', titlesize=SIZE+4)  # fontsize of the axes title
plt.rc('axes', labelsize=SIZE+4)  # fontsize of the x any y labels
plt.rc('xtick', labelsize=SIZE)  # fontsize of the tick labels
plt.rc('ytick', labelsize=SIZE)  # fontsize of the tick labels
plt.rc('legend', fontsize=SIZE+3)  # legend fontsize
#plt.rc('figure', titlesize=SIZE)  # # size of the figure title


nek=e0.get('nek')
ks=np.linspace(1,nek,nek)
ek_all=e0.get('ek_all')
ek_gaussian=e0.get('ek_gaussian')
ek_sharp=e0.get('ek_sharp')
ek_box=e0.get('ek_box')

plt.figure(figsize=(6,6))
plt.loglog(ks,ek_all,'r',label='Unfiltered')
plt.loglog(ks,ek_gaussian,'b',label='Gaussian ($\kappa_c=100$)')
plt.loglog(ks,ek_sharp,'g',label='Sharp ($\kappa_c=100$)')
plt.loglog(ks,ek_box,'y',label='Box ($\kappa_c=100$)')
plt.loglog(ks,np.power(ks,-5/3),'k')
plt.loglog([100,100],[1.e-10,1],'k--')
plt.xlabel('$\kappa$')
plt.ylabel('$E(\kappa)$')
plt.axis([0.0,1000.0, 1e-10,1.0])
plt.legend(loc=0, shadow=True) #loc='upper center'
ax = plt.gca()
ax.set_autoscale_on(False)
plt.savefig('EnrgySpec_all.eps', format='eps', dpi=1200)
