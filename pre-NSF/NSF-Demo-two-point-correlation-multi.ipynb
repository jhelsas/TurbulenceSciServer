# %% [markdown]
# This notebook is to exemplify the obtention one of power law of a single treshold of the 2-point correlation function of enstrophy excursion sets. The objective is to provide an interactive enviroment to test different thresholds and provide a feel of what is the behavior of the system.

# %%
#!ipcluster start -n 8 --engines=MPI --profile='mpi' # for parallel run: start the engines using terminal
from ipyparallel import Client
rc = Client(profile='mpi')

# %% [markdown]
# Following suit, it is necessary to import the libraries that are necessary to the work to be executed. These include  numpy for the generay array manipulations, pyFFTW to the Fourier Transforms, mpi4py for MPI support, general math, sys and os libraries and pyJHTDB, that provides a python wraper for the C-SOAP interface of the Johs Hopkins Turbulence Databases. We also import some modules that provide basic 3D FFT and histograming functionality build upon numpy and pyFFTW, as a way to streamline the overall process. Those modules, which include FFT3Dfield, IFFT3Dfield and EnergySpectrum, were originaly developed by Dr. Kun Yang.

# %%
# %%px
# # Import the libraries
#
# import os
# import sys
# import math
# import numpy as np
# import pyfftw as ft
# from mpi4py import MPI
# import matplotlib
# import matplotlib.pyplot as plt
# import pyJHTDB
# from pyJHTDB.dbinfo import isotropic1024coarse
# from pyJHTDB import libJHTDB
#
# from fft3d import FFT3Dfield_new
# from EnergySpectrum import EnergySpectrum

# %% [markdown]
# We first initialize general domain constants, based on the isotropic1024coarse dictionary, which provide information on the isotropic turbulence database. We then initialize MPI variables, including the communicator, rank and number of process. The typical number of processes is 8, both because it doesn't, usually, overloads the sciserver hardware, but also it is the optimal number of processes to query the database. Afterwards, it is necessary to initalize the variables that designate the domain associated with each MPI process. Due to the way that the FFT3D modules were build, we chose to divide the domain in slabs split in the X direction. Also, constants related to wavenumber and chunck size downloads are initialized.

# %%
# %%px
#
# Nx = isotropic1024coarse['nx']; Ny = isotropic1024coarse['ny']; Nz = isotropic1024coarse['nz']
# Lx = isotropic1024coarse['lx']; Ly = isotropic1024coarse['ly']; Lz = isotropic1024coarse['lz']
#
# comm = MPI.COMM_WORLD
# rank = comm.Get_rank()
# nproc = comm.Get_size()
# if(rank==0):
#     print("n_proc = "+str(nproc))
#     print("rank = "+str(rank))
#
# # Computational Domain
#
# nx=Nx//nproc; ny=Ny; nz=Nz
# nz_half=nz//2
# nek=int(math.sqrt(2.0)/3*Nx)
# time = 0.0
#
# chkSz = 32
# slabs = nx//chkSz
# Out:
# [stdout:4]
# n_proc = 8
# rank = 0

# %% [markdown]
# Instead of downloading the velocity field from the website, we just load the cached value of enstrophy pre-computed from a previous notebook. On vm01 it takes between 60 to 90 seconds to load from disk. On vm04 is taking less than 6 seconds to load.

# %%
# %%px
#
# cacheEnstrophyData = False
# loadEnstrophyFromCache = True
#
# folder = "/home/idies/workspace/scratch"
# filename = "ref-enstrophy-"+str(rank)+".npz"
# file = folder + "/" + filename
#
# if(loadEnstrophyFromCache):
#     comm.Barrier(); t1=MPI.Wtime()
#     content = np.load(file)
#
#     w2 = ft.zeros_aligned((nx,ny,nz), dtype='float32')
#
#     if(int(content['nproc'])!=nproc):
#         print("Unmatched number of processes. Must first pre-process to adequate number of process")
#     w2[:,:,:] = content['w2']
#
#     comm.Barrier(); t2=MPI.Wtime()
#     if(rank==0):
#         print("Finished loading")
#         sys.stdout.write('Load from disk: {0:.2f} seconds\n'.format(t2-t1))
#
# if(cacheEnstrophyData):
#
#     comm.Barrier(); t1=MPI.Wtime()
#     np.savez(file,w2=w2,nproc=nproc)
#     comm.Barrier(); t2=MPI.Wtime()
#     if(rank==0):
#         sys.stdout.write('Caching the data: {0:.2f} seconds\n'.format(t2-t1))
# Out:
# [stdout:4]
# Finished loading
# Load from disk: 20.96 seconds

# %% [markdown]
# We compute the global average of enstrophy. And also we compute minimum and maximum values of enstrophy, for reference.

# %%
# %%px
#
# avgOmega = np.average(w2)
# avgOmegaGl=np.zeros(1,dtype='float32')
#
# comm.Reduce([avgOmega,MPI.REAL],[avgOmegaGl,MPI.REAL],op=MPI.SUM)
# avgOmega = avgOmegaGl[0]/nproc
# avgOmega = comm.bcast(avgOmega, root=0)
#
# ##########################
#
# minw2 = w2.min()
# maxw2 = w2.max()
#
# minwGl=np.zeros(nproc,dtype='float32')
# maxwGl=np.zeros(nproc,dtype='float32')
#
# comm.Allgather([minw2,MPI.REAL],[minwGl,MPI.REAL])
# comm.Allgather([maxw2,MPI.REAL],[maxwGl,MPI.REAL])
#
# minw2 = minwGl.min()
# maxw2 = maxwGl.max()
#
# comm.Barrier()
#
# if rank==0:
#     print("<w^2> : "+str(avgOmega))
#     print("min w2/<w^2> : "+str(minw2/avgOmega))
#     print("min w2/<w^2> : "+str(maxw2/avgOmega))
# Out:
# [stdout:4]
# <w^2> : 498.43548584
# min w2/<w^2> : 1.43020472082e-07
# min w2/<w^2> : 675.170126447

# %% [markdown]
# Here we need to alocate all arrays we need to do the calculations of the 2-point correlation function. Since there are many arrays to be alocated at the same time, it takes a fair amount of time. On vm01, it takes around 160 to 190 seconds. On vm04, is taking around 25 seconds to load, with some times running below 7 seconds.

# %%
# %%px
#
# dx = isotropic1024coarse['dx']
# ner = int(1024*np.sqrt(3))
# rbins = np.linspace(-0.5*dx,2*np.pi*np.sqrt(3)+0.5*dx,ner+1)
#
# comm.Barrier(); t1=MPI.Wtime()
#
# fft = FFT3Dfield_new(nx,ny,nz,nproc,rank)
#
# X = np.zeros((nx,ny,nz), dtype='float32')
# Y = np.zeros((nx,ny,nz), dtype='float32')
# Z = np.zeros((nx,ny,nz), dtype='float32')
#
# r2 = np.zeros((nx,ny,nz), dtype='float32')
#
# chi = ft.zeros_aligned((nx,ny,nz), dtype='float32')
# cchi = ft.zeros_aligned((nx,ny,1+(nz//2)), dtype='complex64')
# corr = ft.zeros_aligned((nx,ny,nz),dtype='float32')
# iCorr = np.zeros((nx,ny,nz), dtype='float32')
#
# corrSum=np.zeros(ner,dtype='float32')
# corrF=np.zeros(ner,dtype='float32')
#
# r2Sum=np.zeros(ner,dtype='float32')
# r2F=np.zeros(ner,dtype='float32')
#
# comm.Barrier(); t2=MPI.Wtime()
# if(rank==0):
#     sys.stdout.write('Alocating vectors: {0:.2f} seconds\n'.format(t2-t1))
# Out:
# [stdout:4] Alocating vectors: 53.23 seconds

# %% [markdown]
# To properly arrange the real space radius to do the spherical integration, we need to assign the distance from the first coordinate, so we compute X, Y and Z arrays, with the respective coordinates, and from there we compute the distance squared to the origin. This is so because the relevant information is contained in the first octant, so all we need is to integrate spherically the first octant. This section takes a fair share of time, around 200-220 seconds. On vm04 is taking around 25 seconds.

# %%
# %%px
#
# comm.Barrier(); t1=MPI.Wtime()
# for i in range(nx):
#     if (i+rank*nx < Nx//2):
#         X[i,:,:] = (i+rank*nx)*isotropic1024coarse['dx']
#     else:
#         X[i,:,:] = Lx-(i+rank*nx)*isotropic1024coarse['dx']
#
# for j in range(ny):
#     if (j < Ny//2):
#         Y[:,j,:] = j*isotropic1024coarse['dy']
#     else:
#         Y[:,j,:] = Ly-j*isotropic1024coarse['dy']
#
# for k in range(nz):
#     if (k < Nz//2):
#         Z[:,:,k] = k*isotropic1024coarse['dz']
#     else:
#         Z[:,:,k] = Lz-k*isotropic1024coarse['dz']
#
# r2[:,:,:] = X[:,:,:]**2+Y[:,:,:]**2+Z[:,:,:]**2
#
# r2rt = np.sqrt(r2)
# comm.Barrier(); t2=MPI.Wtime()
# if(rank==0):
#     sys.stdout.write('Preparing the real domain for radial integration: {0:.2f} seconds\n'.format(t2-t1))
# Out:
# [stdout:4] Preparing the real domain for radial integration: 45.11 seconds

# %% [markdown]
# The computation of the full radial 2-point correlation function is done here, including the fourier transform and radial integration. The full computation takes around 80 seconds, on VM04. The breakdown time measured is:
#
# Creating the excursion set: 1.18 seconds
#
# Computing the 2-point correlation function: 48.87 seconds
#
# Cleaning all but the 1st octant: 2.15 seconds
#
# Integrating radially on each slab: 29.60 seconds
#
# Adding the results form different slabs: 0.00 seconds
#
# Full radial 2-point correlation calculation: 81.80 seconds

# %%
# %%px
# %matplotlib inline
#
# t = [1,2,3,4,5,6]
# c = ['r','g','b','c','y','m']
#
# hist = []
# r2st = []
#
# for i in range(6):
#     if(rank==0):
#         print("Treshold = "+str(t[i]))
#
#     #######################################
#     comm.Barrier(); t1=MPI.Wtime()
#
#     chi[:,:,:] = 0
#     chi[w2 > t[i]*avgOmega] = 1
#
#     #######################################
#
#     comm.Barrier(); t2=MPI.Wtime()
#     cchi[:,:,:] = fft.forward3Dfft(chi,nx,ny,nz,nproc,rank)
#
#     tmp = cchi*(cchi.conj())
#     corr[:,:,:] = fft.backward3Dfft(tmp,nx,ny,nz,nproc,rank)
#
#     #######################################
#
#     comm.Barrier(); t3=MPI.Wtime()
#
#     #######################################
#
#     comm.Barrier(); t4=MPI.Wtime()
#
#     corrLoc,redges = np.histogram(r2rt,range=(0.5*dx,(ner+0.5)*dx),bins = rbins,weights=corr)
#
#     r2Loc,r2edges = np.histogram(r2rt,range=(0.5*dx,(ner+0.5)*dx),bins = rbins)
#
#     #######################################
#
#     comm.Barrier(); t5=MPI.Wtime()
#
#     corrLoc=np.float32(corrLoc)
#     comm.Reduce([corrLoc,MPI.REAL],[corrSum,MPI.REAL],op=MPI.SUM)
#     np.copyto(corrF,corrSum)
#
#     corrApend=np.zeros(ner,dtype='float32')
#     corrApend[:] = corrF[:]
#
#     #########################
#
#     r2Loc=np.float32(r2Loc)
#     comm.Reduce([r2Loc,MPI.REAL],[r2Sum,MPI.REAL],op=MPI.SUM)
#     np.copyto(r2F,r2Sum)
#
#     r2Apend=np.zeros(ner,dtype='float32')
#     r2Apend[:] = r2F[:]
#
#     if rank==0:
#         hist.append(corrApend[:])
#         r2st.append(r2Apend[:])
#
#     #######################################
#
#     comm.Barrier(); t6=MPI.Wtime()
#
#     if rank==0:
#         sys.stdout.write('threshold used: {0:.2f} \n'.format(t[i]))
#         sys.stdout.write('Creating the excursion set: {0:.2f} seconds\n'.format(t2-t1))
#         sys.stdout.write('Computing the 2-point correlation function: {0:.2f} seconds\n'.format(t3-t2))
#         sys.stdout.write('Cleaning all but the 1st octant: {0:.2f} seconds\n'.format(t4-t3))
#         sys.stdout.write('Integrating radially on each slab: {0:.2f} seconds\n'.format(t5-t4))
#         sys.stdout.write('Adding the results form different slabs: {0:.2f} seconds\n'.format(t6-t5))
#         sys.stdout.write('Full radial 2-point correlation calculation: {0:.2f} seconds\n'.format(t6-t1))
#         sys.stdout.write('\n')
# Out:
# [stdout:4]
# Treshold = 1
# threshold used: 1.00
# Creating the excursion set: 10.28 seconds
# Computing the 2-point correlation function: 81.22 seconds
# Cleaning all but the 1st octant: 0.00 seconds
# Integrating radially on each slab: 31.67 seconds
# Adding the results form different slabs: 0.00 seconds
# Full radial 2-point correlation calculation: 123.18 seconds
#
# Treshold = 2
# threshold used: 2.00
# Creating the excursion set: 3.70 seconds
# Computing the 2-point correlation function: 59.86 seconds
# Cleaning all but the 1st octant: 0.00 seconds
# Integrating radially on each slab: 31.80 seconds
# Adding the results form different slabs: 0.01 seconds
# Full radial 2-point correlation calculation: 95.38 seconds
#
# Treshold = 3
# threshold used: 3.00
# Creating the excursion set: 6.98 seconds
# Computing the 2-point correlation function: 59.68 seconds
# Cleaning all but the 1st octant: 0.00 seconds
# Integrating radially on each slab: 32.01 seconds
# Adding the results form different slabs: 0.00 seconds
# Full radial 2-point correlation calculation: 98.67 seconds
#
# Treshold = 4
# threshold used: 4.00
# Creating the excursion set: 3.22 seconds
# Computing the 2-point correlation function: 58.09 seconds
# Cleaning all but the 1st octant: 0.00 seconds
# Integrating radially on each slab: 31.47 seconds
# Adding the results form different slabs: 0.00 seconds
# Full radial 2-point correlation calculation: 92.78 seconds
#
# Treshold = 5
# threshold used: 5.00
# Creating the excursion set: 3.49 seconds
# Computing the 2-point correlation function: 57.41 seconds
# Cleaning all but the 1st octant: 0.00 seconds
# Integrating radially on each slab: 31.29 seconds
# Adding the results form different slabs: 0.01 seconds
# Full radial 2-point correlation calculation: 92.19 seconds
#
# Treshold = 6
# threshold used: 6.00
# Creating the excursion set: 6.74 seconds
# Computing the 2-point correlation function: 59.67 seconds
# Cleaning all but the 1st octant: 0.00 seconds
# Integrating radially on each slab: 32.31 seconds
# Adding the results form different slabs: 0.00 seconds
# Full radial 2-point correlation calculation: 98.72 seconds

# %% [markdown]
# Finally, plotting the results:

# %%
# %%px
#
# if(rank==0):
#     matplotlib.rc('xtick', labelsize=20)
#     matplotlib.rc('ytick', labelsize=20)
#
#     idx = r2st[0]>0
#
#     rp=np.linspace(1*dx,ner*dx,ner)
#
#     lrp = rp[idx]
#
#     tempRp = lrp[(lrp>0.1)&(lrp<1.0)]
#     plt.figure(figsize=(12,12))
#     plt.xlabel(r'$r$', fontsize=20)
#     plt.ylabel(r'$\frac{C(r)}{C(0)} = \frac{1}{C(0)} \int_{S^2} \langle \chi({\bf x}) \chi({\bf x}+{\bf r}) \rangle d\Omega$', fontsize=20)
#     plt.xlim([7*10**(-3),np.pi])
#     plt.ylim([10**(-2),2*10**0])
#     plt.grid()
#
#     for i in range(6):
#         corrF1 = hist[i][idx]/r2st[i][idx]
#
#         tempCorrF = corrF1[(lrp>0.1)&(lrp<1.0)]
#
#         ctmp = (corrF1[300])/(corrF1[0])
#
#         fit = np.polyfit(np.log(tempRp),np.log(tempCorrF/corrF1[0]),1)
#         print("t = "+str(t[i])+"*sigma_2: Linear fit [alpha A] = "+str(fit))
#
#         plt.loglog(lrp,(corrF1)/(corrF1[0]),c[i],label=r'$\omega^2 > '+str(t[i])
#                                                    +r'\langle \omega^2\rangle$ : $\alpha ='
#                                                    +str(fit[0])+r'$')
#
#         corrF1 = hist[i][idx]
#
#         plt.loglog(lrp,np.exp(fit[1])*(lrp**(fit[0])),'k--')
#
#     plt.legend(loc='lower left',prop={'size':16})
# Out:
# [stdout:4]
# t = 1*sigma_2: Linear fit [alpha A] = [-0.10921099 -1.41209709]
# t = 2*sigma_2: Linear fit [alpha A] = [-0.18944022 -2.08677832]
# t = 3*sigma_2: Linear fit [alpha A] = [-0.25261056 -2.56865734]
# t = 4*sigma_2: Linear fit [alpha A] = [-0.30578336 -2.95148515]
# t = 5*sigma_2: Linear fit [alpha A] = [-0.35221311 -3.27228269]
# t = 6*sigma_2: Linear fit [alpha A] = [-0.39372816 -3.55018583]
# [output:4]

# %%
# %%px
# %matplotlib inline
#
# t = [7,10,15,20,30,50]
# c = ['r','g','b','c','y','m']
#
# hist = []
# r2st = []
#
# for i in range(6):
#     if(rank==0):
#         print("Treshold = "+str(t[i]))
#
#     #######################################
#     comm.Barrier(); t1=MPI.Wtime()
#
#     chi[:,:,:] = 0
#     chi[w2 > t[i]*avgOmega] = 1
#
#     #######################################
#
#     comm.Barrier(); t2=MPI.Wtime()
#     cchi[:,:,:] = fft.forward3Dfft(chi,nx,ny,nz,nproc,rank)
#
#     tmp = cchi*(cchi.conj())
#     corr[:,:,:] = fft.backward3Dfft(tmp,nx,ny,nz,nproc,rank)
#
#     #######################################
#
#     comm.Barrier(); t3=MPI.Wtime()
#
#     #######################################
#
#     comm.Barrier(); t4=MPI.Wtime()
#
#     corrLoc,redges = np.histogram(r2rt,range=(0.5*dx,(ner+0.5)*dx),bins = rbins,weights=corr)
#
#     r2Loc,r2edges = np.histogram(r2rt,range=(0.5*dx,(ner+0.5)*dx),bins = rbins)
#
#     #######################################
#
#     comm.Barrier(); t5=MPI.Wtime()
#
#     corrLoc=np.float32(corrLoc)
#     comm.Reduce([corrLoc,MPI.REAL],[corrSum,MPI.REAL],op=MPI.SUM)
#     np.copyto(corrF,corrSum)
#
#     corrApend=np.zeros(ner,dtype='float32')
#     corrApend[:] = corrF[:]
#
#     #########################
#
#     r2Loc=np.float32(r2Loc)
#     comm.Reduce([r2Loc,MPI.REAL],[r2Sum,MPI.REAL],op=MPI.SUM)
#     np.copyto(r2F,r2Sum)
#
#     r2Apend=np.zeros(ner,dtype='float32')
#     r2Apend[:] = r2F[:]
#
#     if rank==0:
#         hist.append(corrApend[:])
#         r2st.append(r2Apend[:])
#
#     #######################################
#
#     comm.Barrier(); t6=MPI.Wtime()
#
#     if rank==0:
#         sys.stdout.write('threshold used: {0:.2f} \n'.format(t[i]))
#         sys.stdout.write('Creating the excursion set: {0:.2f} seconds\n'.format(t2-t1))
#         sys.stdout.write('Computing the 2-point correlation function: {0:.2f} seconds\n'.format(t3-t2))
#         sys.stdout.write('Cleaning all but the 1st octant: {0:.2f} seconds\n'.format(t4-t3))
#         sys.stdout.write('Integrating radially on each slab: {0:.2f} seconds\n'.format(t5-t4))
#         sys.stdout.write('Adding the results form different slabs: {0:.2f} seconds\n'.format(t6-t5))
#         sys.stdout.write('Full radial 2-point correlation calculation: {0:.2f} seconds\n'.format(t6-t1))
#         sys.stdout.write('\n')
# Out:
# [stdout:4]
# Treshold = 7
# threshold used: 7.00
# Creating the excursion set: 6.80 seconds
# Computing the 2-point correlation function: 77.08 seconds
# Cleaning all but the 1st octant: 0.00 seconds
# Integrating radially on each slab: 31.66 seconds
# Adding the results form different slabs: 0.00 seconds
# Full radial 2-point correlation calculation: 115.54 seconds
#
# Treshold = 10
# threshold used: 10.00
# Creating the excursion set: 6.32 seconds
# Computing the 2-point correlation function: 65.37 seconds
# Cleaning all but the 1st octant: 0.00 seconds
# Integrating radially on each slab: 31.79 seconds
# Adding the results form different slabs: 0.00 seconds
# Full radial 2-point correlation calculation: 103.49 seconds
#
# Treshold = 15
# threshold used: 15.00
# Creating the excursion set: 3.63 seconds
# Computing the 2-point correlation function: 58.90 seconds
# Cleaning all but the 1st octant: 0.00 seconds
# Integrating radially on each slab: 31.55 seconds
# Adding the results form different slabs: 0.01 seconds
# Full radial 2-point correlation calculation: 94.09 seconds
#
# Treshold = 20
# threshold used: 20.00
# Creating the excursion set: 6.82 seconds
# Computing the 2-point correlation function: 64.93 seconds
# Cleaning all but the 1st octant: 0.00 seconds
# Integrating radially on each slab: 31.58 seconds
# Adding the results form different slabs: 0.00 seconds
# Full radial 2-point correlation calculation: 103.33 seconds
#
# Treshold = 30
# threshold used: 30.00
# Creating the excursion set: 3.33 seconds
# Computing the 2-point correlation function: 56.05 seconds
# Cleaning all but the 1st octant: 0.00 seconds
# Integrating radially on each slab: 32.04 seconds
# Adding the results form different slabs: 0.00 seconds
# Full radial 2-point correlation calculation: 91.43 seconds
#
# Treshold = 50
# threshold used: 50.00
# Creating the excursion set: 3.45 seconds
# Computing the 2-point correlation function: 56.31 seconds
# Cleaning all but the 1st octant: 0.00 seconds
# Integrating radially on each slab: 31.52 seconds
# Adding the results form different slabs: 0.01 seconds
# Full radial 2-point correlation calculation: 91.28 seconds

# %%
# %%px
#
# if(rank==0):
#     matplotlib.rc('xtick', labelsize=20)
#     matplotlib.rc('ytick', labelsize=20)
#
#     idx = r2st[0]>0
#
#     rp=np.linspace(1*dx,ner*dx,ner)
#
#     lrp = rp[idx]
#
#     tempRp = lrp[(lrp>0.1)&(lrp<1.0)]
#     plt.figure(figsize=(12,12))
#     plt.xlabel(r'$r$', fontsize=20)
#     plt.ylabel(r'$\frac{C(r)}{C(0)} = \frac{1}{C(0)} \int_{S^2} \langle \chi({\bf x}) \chi({\bf x}+{\bf r}) \rangle d\Omega$', fontsize=20)
#     plt.xlim([7*10**(-3),np.pi])
#     plt.ylim([10**(-4),2*10**0])
#     plt.grid()
#
#     for i in range(6):
#         corrF1 = hist[i][idx]/r2st[i][idx]
#
#         tempCorrF = corrF1[(lrp>0.1)&(lrp<1.0)]
#
#         ctmp = (corrF1[300])/(corrF1[0])
#
#         fit = np.polyfit(np.log(tempRp),np.log(tempCorrF/corrF1[0]),1)
#         print("t = "+str(t[i])+"*sigma_2: Linear fit [alpha A] = "+str(fit))
#
#         plt.loglog(lrp,(corrF1)/(corrF1[0]),c[i],label=r'$\omega^2 > '+str(t[i])
#                                                    +r'\langle \omega^2\rangle$ : $\alpha ='
#                                                    +str(fit[0])+r'$')
#
#         corrF1 = hist[i][idx]
#
#         plt.loglog(lrp,np.exp(fit[1])*(lrp**(fit[0])),'k--')
#
#     plt.legend(loc='lower left',prop={'size':16})
# Out:
# [stdout:4]
# t = 7*sigma_2: Linear fit [alpha A] = [-0.43127754 -3.79613703]
# t = 10*sigma_2: Linear fit [alpha A] = [-0.52659139 -4.40524371]
# t = 15*sigma_2: Linear fit [alpha A] = [-0.6505599 -5.1674624]
# t = 20*sigma_2: Linear fit [alpha A] = [-0.74922923 -5.7554543 ]
# t = 30*sigma_2: Linear fit [alpha A] = [-0.90409856 -6.66024914]
# t = 50*sigma_2: Linear fit [alpha A] = [-1.13918616 -7.94937597]
# [output:4]

# %%
# %%px
# %matplotlib inline
#
# t = [60,75,100,125,150,200]
# c = ['r','g','b','c','y','m']
#
# hist = []
# r2st = []
#
# for i in range(6):
#     if(rank==0):
#         print("Treshold = "+str(t[i]))
#
#     #######################################
#     comm.Barrier(); t1=MPI.Wtime()
#
#     chi[:,:,:] = 0
#     chi[w2 > t[i]*avgOmega] = 1
#
#     #######################################
#
#     comm.Barrier(); t2=MPI.Wtime()
#     cchi[:,:,:] = fft.forward3Dfft(chi,nx,ny,nz,nproc,rank)
#
#     tmp = cchi*(cchi.conj())
#     corr[:,:,:] = fft.backward3Dfft(tmp,nx,ny,nz,nproc,rank)
#
#     #######################################
#
#     comm.Barrier(); t3=MPI.Wtime()
#
#     #######################################
#
#     comm.Barrier(); t4=MPI.Wtime()
#
#     corrLoc,redges = np.histogram(r2rt,range=(0.5*dx,(ner+0.5)*dx),bins = rbins,weights=corr)
#
#     r2Loc,r2edges = np.histogram(r2rt,range=(0.5*dx,(ner+0.5)*dx),bins = rbins)
#
#     #######################################
#
#     comm.Barrier(); t5=MPI.Wtime()
#
#     corrLoc=np.float32(corrLoc)
#     comm.Reduce([corrLoc,MPI.REAL],[corrSum,MPI.REAL],op=MPI.SUM)
#     np.copyto(corrF,corrSum)
#
#     corrApend=np.zeros(ner,dtype='float32')
#     corrApend[:] = corrF[:]
#
#     #########################
#
#     r2Loc=np.float32(r2Loc)
#     comm.Reduce([r2Loc,MPI.REAL],[r2Sum,MPI.REAL],op=MPI.SUM)
#     np.copyto(r2F,r2Sum)
#
#     r2Apend=np.zeros(ner,dtype='float32')
#     r2Apend[:] = r2F[:]
#
#     if rank==0:
#         hist.append(corrApend[:])
#         r2st.append(r2Apend[:])
#
#     #######################################
#
#     comm.Barrier(); t6=MPI.Wtime()
#
#     if rank==0:
#         sys.stdout.write('threshold used: {0:.2f} \n'.format(t[i]))
#         sys.stdout.write('Creating the excursion set: {0:.2f} seconds\n'.format(t2-t1))
#         sys.stdout.write('Computing the 2-point correlation function: {0:.2f} seconds\n'.format(t3-t2))
#         sys.stdout.write('Cleaning all but the 1st octant: {0:.2f} seconds\n'.format(t4-t3))
#         sys.stdout.write('Integrating radially on each slab: {0:.2f} seconds\n'.format(t5-t4))
#         sys.stdout.write('Adding the results form different slabs: {0:.2f} seconds\n'.format(t6-t5))
#         sys.stdout.write('Full radial 2-point correlation calculation: {0:.2f} seconds\n'.format(t6-t1))
#         sys.stdout.write('\n')
# Out:
# [stdout:4]
# Treshold = 60
# threshold used: 60.00
# Creating the excursion set: 6.54 seconds
# Computing the 2-point correlation function: 63.15 seconds
# Cleaning all but the 1st octant: 0.00 seconds
# Integrating radially on each slab: 32.37 seconds
# Adding the results form different slabs: 0.00 seconds
# Full radial 2-point correlation calculation: 102.07 seconds
#
# Treshold = 75
# threshold used: 75.00
# Creating the excursion set: 3.38 seconds
# Computing the 2-point correlation function: 57.53 seconds
# Cleaning all but the 1st octant: 0.00 seconds
# Integrating radially on each slab: 32.33 seconds
# Adding the results form different slabs: 0.00 seconds
# Full radial 2-point correlation calculation: 93.24 seconds
#
# Treshold = 100
# threshold used: 100.00
# Creating the excursion set: 3.59 seconds
# Computing the 2-point correlation function: 57.08 seconds
# Cleaning all but the 1st octant: 0.00 seconds
# Integrating radially on each slab: 31.28 seconds
# Adding the results form different slabs: 0.00 seconds
# Full radial 2-point correlation calculation: 91.95 seconds
#
# Treshold = 125
# threshold used: 125.00
# Creating the excursion set: 5.70 seconds
# Computing the 2-point correlation function: 61.87 seconds
# Cleaning all but the 1st octant: 0.00 seconds
# Integrating radially on each slab: 30.89 seconds
# Adding the results form different slabs: 0.00 seconds
# Full radial 2-point correlation calculation: 98.46 seconds
#
# Treshold = 150
# threshold used: 150.00
# Creating the excursion set: 3.14 seconds
# Computing the 2-point correlation function: 57.03 seconds
# Cleaning all but the 1st octant: 0.00 seconds
# Integrating radially on each slab: 30.62 seconds
# Adding the results form different slabs: 0.00 seconds
# Full radial 2-point correlation calculation: 90.79 seconds
#
# Treshold = 200
# threshold used: 200.00
# Creating the excursion set: 3.42 seconds
# Computing the 2-point correlation function: 57.18 seconds
# Cleaning all but the 1st octant: 0.00 seconds
# Integrating radially on each slab: 33.64 seconds
# Adding the results form different slabs: 0.01 seconds
# Full radial 2-point correlation calculation: 94.25 seconds

# %%
# %%px
#
# if(rank==0):
#     matplotlib.rc('xtick', labelsize=20)
#     matplotlib.rc('ytick', labelsize=20)
#
#     idx = r2st[0]>0
#
#     rp=np.linspace(1*dx,ner*dx,ner)
#
#     lrp = rp[idx]
#
#     tempRp = lrp[(lrp>0.1)&(lrp<1.0)]
#     plt.figure(figsize=(12,12))
#     plt.xlabel(r'$r$', fontsize=20)
#     plt.ylabel(r'$\frac{C(r)}{C(0)} = \frac{1}{C(0)} \int_{S^2} \langle \chi({\bf x}) \chi({\bf x}+{\bf r}) \rangle d\Omega$', fontsize=20)
#     plt.xlim([7*10**(-3),np.pi])
#     plt.ylim([10**(-7),2*10**0])
#     plt.grid()
#
#     for i in range(6):
#         corrF1 = hist[i][idx]/r2st[i][idx]
#
#         tempCorrF = corrF1[(lrp>0.1)&(lrp<1.0)]
#
#         ctmp = (corrF1[300])/(corrF1[0])
#
#         fit = np.polyfit(np.log(tempRp),np.log(tempCorrF/corrF1[0]),1)
#         print("t = "+str(t[i])+"*sigma_2: Linear fit [alpha A] = "+str(fit))
#
#         plt.loglog(lrp,(corrF1)/(corrF1[0]),c[i],label=r'$\omega^2 > '+str(t[i])
#                                                    +r'\langle \omega^2\rangle$ : $\alpha ='
#                                                    +str(fit[0])+r'$')
#
#         corrF1 = hist[i][idx]
#
#         plt.loglog(lrp,np.exp(fit[1])*(lrp**(fit[0])),'k--')
#
#     plt.legend(loc='lower left',prop={'size':16})
# Out:
# [stdout:4]
# t = 60*sigma_2: Linear fit [alpha A] = [-1.23587784 -8.46849326]
# t = 75*sigma_2: Linear fit [alpha A] = [-1.3664229  -9.15080435]
# t = 100*sigma_2: Linear fit [alpha A] = [ -1.53872556 -10.11119404]
# t = 125*sigma_2: Linear fit [alpha A] = [ -1.68615294 -10.94750157]
# t = 150*sigma_2: Linear fit [alpha A] = [ -1.77573285 -11.64564287]
# t = 200*sigma_2: Linear fit [alpha A] = [ -1.95125025 -12.93424384]
# [output:4]
