# %%
import h5py
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import os
import pyfftw as ft
import time
import pyJHTDB
from pyJHTDB.dbinfo import isotropic1024coarse
from pyJHTDB import libJHTDB

# %%
t = 1*sigma_2: Linear fit [alpha A] = [-0.1037311  -0.80187054]
t = 2*sigma_2: Linear fit [alpha A] = [-0.18202561 -1.0192294 ]
t = 3*sigma_2: Linear fit [alpha A] = [-0.24496054 -1.13519577]
t = 1*sigma_2: Linear fit [alpha A] = [-0.14190173 -0.39593325]
t = 2*sigma_2: Linear fit [alpha A] = [-0.27253386 -0.44104948]
t = 3*sigma_2: Linear fit [alpha A] = [-0.38051184 -0.41303416]
    
t = 4*sigma_2: Linear fit [alpha A] = [-0.29875631 -1.20635975]
t = 5*sigma_2: Linear fit [alpha A] = [-0.34622119 -1.2527781 ]
t = 6*sigma_2: Linear fit [alpha A] = [-0.38919419 -1.28306311]
t = 4*sigma_2: Linear fit [alpha A] = [-0.47323264 -0.36091899]
t = 5*sigma_2: Linear fit [alpha A] = [-0.55481593 -0.30024413]
t = 6*sigma_2: Linear fit [alpha A] = [-0.62780744 -0.2378036 ]

# %%
DimsCorr = [3-0.1037311,3-0.1820256,3-0.24496054,3-0.29875631,3-0.34622119,3-0.38919419,2.55707298991,2.45478850655,2.32089057834,2.21559905325,2.05073255571,1.81537386465]

# %%
print(DimsCorr)
# Out:
# [2.8962689, 2.8179743999999998, 2.75503946, 2.70124369, 2.65377881, 2.61080581, 2.55707298991, 2.45478850655, 2.32089057834, 2.21559905325, 2.05073255571, 1.81537386465]

# %%
Total =  187.4784505367279  t = 50
t = 50*sigma_2: Linear fit [alpha A] = [-1.7956574   5.89409759]
Total =  241.59092116355896  t = 30
t = 30*sigma_2: Linear fit [alpha A] = [-2.19481454  5.90513973]
Total =  372.9878942966461  t = 20
t = 20*sigma_2: Linear fit [alpha A] = [-2.44356983  5.86895458]
Total =  568.259667634964  t = 15
t = 15*sigma_2: Linear fit [alpha A] = [-2.58030611  5.83582359]
Total =  1066.7805194854736  t = 10
t = 10*sigma_2: Linear fit [alpha A] = [-2.71984582  5.79217321]
Total =  1897.399052143097  t = 7
t = 7*sigma_2: Linear fit [alpha A] = [-2.79893884  5.76353198]
Total =  2361.100456237793  t = 6
t = 6*sigma_2: Linear fit [alpha A] = [-2.8231021   5.75430296]
Total =  3086.199568748474  t = 5
t = 5*sigma_2: Linear fit [alpha A] = [-2.84487106  5.74544856]
Total =  4100.888454437256  t = 4
t = 4*sigma_2: Linear fit [alpha A] = [-2.8643779   5.73721648]
Total =  6022.5185034275055  t = 3
t = 3*sigma_2: Linear fit [alpha A] = [-2.88075216  5.73011772]
Total =  9831.642573595047  t = 2
t = 2*sigma_2: Linear fit [alpha A] = [-2.89302054  5.72460295]
Total =  19836.86435174942  t = 1
t = 1*sigma_2: Linear fit [alpha A] = [-2.89930749  5.72166221]

# %%
DimsBox = [2.89930749,2.89302054,2.88075216,2.8643779,2.84487106,2.8231021,2.79893884,2.71984582,2.58030611,2.44356983,2.19481454,1.7956574]

# %%
fig = plt.figure(figsize=(9,9))
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 
plt.xlim([1.6,3.0])
plt.ylim([1.6,3.0])
plt.xlabel(r'$D_{corr}$',size=30)
plt.ylabel(r'$D_{box}$',size=30)
xax = np.linspace(1.6,3.0,100)
plt.axes().set_aspect('equal')
plt.plot(DimsCorr,DimsBox,'x')
plt.plot(xax,xax)
plt.savefig('DimCorr_x_Box-comparison.pdf')

# %%
t = [1,2,3,4,5,6,7,10,15,20,30,50]
fig = plt.figure(figsize=(9,9))
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 
plt.xlim([0,52.0])
plt.ylim([1.6,3.0])
plt.ylabel(r'$D_{corr},D_{box}$',size=30)
plt.xlabel(r'$t$',size=30)
#plt.axes().set_aspect('equal')
plt.plot(t,DimsCorr,'x-',label='Correlation')
plt.plot(t,DimsBox,'x-',label='Box Counting')
plt.legend(loc='lower left',prop={'size':16})
plt.savefig('DimCorr_x_Box-comparative.pdf')
